# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from decimal import *
import math

# %%
indices=pd.read_csv('Data/indices.csv')

# %%
medias = indices.mean(axis = 0)
desv = indices.std(axis = 0)
datos_norm = (indices - medias) / desv

# %%
indices.head()
# Out:
#    Unnamed: 0  DJ Utility  DJ Composite  CBOE Volatility  \
# 0           0      920.57       11903.5            22.96
# 1           1      906.95       11803.3            28.62
# 2           2      922.85       12136.0            18.58
# 3           3      922.66       12147.6            18.58
# 4           4      921.50       12079.0            19.38
#
#    DJ Industrial Average  NASDAQ 100     NAQC  NYSE Composite  \
# 0               35135.78    16399.24  15782.8         16684.0
# 1               34908.10    16025.58  15491.7         16624.9
# 2               35805.17    16367.81  15845.2         17036.8
# 3               35813.74    16306.72  15775.1         17007.9
# 4               35619.26    16380.98  15854.8         16945.8
#
#    NYSE Market Composite  Russell 200  S&P 100  S&P 500
# 0                 3411.0      2241.98   2151.2  4655.27
# 1                 3394.0      2245.94   2122.4  4594.62
# 2                 3510.9      2334.65   2170.8  4701.46
# ...

# %%
valor_DJU=datos_norm['DJ Utility']
valor_DJC=datos_norm['DJ Composite']
valor_CBOE=datos_norm['CBOE Volatility']
valor_DJ_Industrial=datos_norm['DJ Industrial Average']
valor_NASDAQ100=datos_norm['NASDAQ 100']
valor_NAQC=datos_norm['NAQC']
valor_NYSE=datos_norm['NYSE Composite']
valor_NYSEMC=datos_norm['NYSE Market Composite']
valor_RUS=datos_norm['Russell 200']
valor_SP100=datos_norm['S&P 100']
valor_SP500=datos_norm['S&P 500']

# %%
#Se grafican todos los valores
plt.plot(valor_DJU, color = "red", label="DJ Utility")
plt.plot(valor_DJC, color = "green", label="DJ Composite")
plt.plot(valor_CBOE, color = "magenta",label="CBOE Volatility")
plt.plot(valor_DJ_Industrial, color = "yellow",label="DJ Industrial Average")
plt.plot(valor_NASDAQ100, color = "blue",label="NASDAQ 100")
plt.ylim([-3, 8])
plt.xlabel('Dias')
plt.legend()
plt.show()

# %%
plt.plot(valor_NAQC, color = "cyan", label="NAQC")
plt.plot(valor_NYSE, color = "r", label="NYSE")
plt.plot(valor_NYSEMC, color = "m",label="NYSE Market Composite")
plt.plot(valor_RUS, color = "y",label="Russell 200")
plt.plot(valor_SP100, color = "b",label="S&P100")
plt.plot(valor_SP500, color = "g",label="S&P500")
plt.ylim([-3, 8])
plt.legend()
plt.show()

# %% [markdown]
# A partir de las gráficas se puede observar que el indice CBOE es el que resalta sobre los demás, teniendo un comportamiento considerable a la alza durante el periodo de 380 y 350 días aproximadamente, es decir durante el primer trimestre del año 2019. Aquí continuación una gráfica con todos los índices.

# %%
plt.figure(figsize=(18, 10))
plt.plot(valor_DJU, color = "red", label="DJ Utility")
plt.plot(valor_DJC, color = "green", label="DJ Composite")
plt.plot(valor_CBOE, color = "magenta",label="CBOE Volatility")
plt.plot(valor_DJ_Industrial, color = "yellow",label="DJ Industrial Average")
plt.plot(valor_NASDAQ100, color = "blue",label="NASDAQ 100")
plt.plot(valor_NAQC, color = "cyan", label="NAQC")
plt.plot(valor_NYSE, color = "r", label="NYSE")
plt.plot(valor_NYSEMC, color = "m",label="NYSE Market Composite")
plt.plot(valor_RUS, color = "y",label="Russell 200")
plt.plot(valor_SP100, color = "b",label="S&P100")
plt.plot(valor_SP500, color = "g",label="S&P500")
plt.ylim([-3, 8])
plt.xlabel('Dias')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(18, 10))
plt.plot(valor_DJU, color = "red", label="DJ Utility")
plt.plot(valor_DJC, color = "green", label="DJ Composite")
plt.plot(valor_DJ_Industrial, color = "yellow",label="DJ Industrial Average")
plt.plot(valor_NASDAQ100, color = "blue",label="NASDAQ 100")
plt.plot(valor_NAQC, color = "cyan", label="NAQC")
plt.plot(valor_NYSE, color = "r", label="NYSE")
plt.plot(valor_NYSEMC, color = "m",label="NYSE Market Composite")
plt.plot(valor_RUS, color = "y",label="Russell 200")
plt.plot(valor_SP100, color = "b",label="S&P100")
plt.plot(valor_SP500, color = "g",label="S&P500")
plt.ylim([-3, 8])
plt.xlabel('Dias')
plt.legend()
plt.show()
